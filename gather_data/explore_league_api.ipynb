# %%
import os
import requests

# %%
API_KEY = os.environ.get('RIOT_API_KEY') 

def get_puuid_by_name(gameName,tagLine,region):
    url = f'https://{region}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{gameName}/{tagLine}'
    headers = {'X-Riot-Token': API_KEY}
    response = requests.get(url, headers=headers)
    return response.json()

gameName = 'regulie'  
tagLine="euw"
region= "europe"
summoner_info = get_puuid_by_name(gameName,tagLine,region)
print(summoner_info)
# Out:
# {'puuid': 'e7hPw-s1uSbpm111-IoD5JsPbEaadK9vebntra_N1tecKQu4RrmaU2v9cJeN6HHt2_ligKOWYR2MEQ', 'gameName': 'regulie', 'tagLine': 'EUW'}

# %%
print(API_KEY)
# Out:
# RGAPI-4ab51515-01c9-49cd-ba60-b0fece647101

# %%
API_KEY = os.environ.get('RIOT_API_KEY') 

def get_puuid_by_name(gameName,tagLine,region):
    url = f'https://{region}.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{gameName}/{tagLine}'
    headers = {'X-Riot-Token': API_KEY}
    response = requests.get(url, headers=headers)
    return response.json()

gameName = 'Vasshu Sutanpido'  
tagLine="1996"
region= "asia"
summoner_info = get_puuid_by_name(gameName,tagLine,region)
print(summoner_info)
puuid= summoner_info["puuid"]
# Out:
# {'puuid': 'xktHNd4jzVv3VRHQ_abi2sykYjZ1w3yEfahecne5V01JwFvLPWpUE_4RCknEEwqf9IEkIX20N_YNeQ', 'gameName': 'Vasshu Sutanpido', 'tagLine': '1996'}

# %%
import datetime

# Create a datetime object representing "10 January 2024"
season14_start= datetime.datetime(2024, 1, 10)

print(season14_start)
timestamp_season14_start = int(datetime.datetime.timestamp(season14_start))
print(timestamp_season14_start)
# Out:
# 2024-01-10 00:00:00
# 1704841200

# %%
def get_all_ranked_league_match_by_uuid(puuid,start_date,region,index=0,match_ids=[]):
    url = f'https://{region}.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?startTime={start_date}&queue=420&type=ranked&start={index}&count=100'
    headers = {'X-Riot-Token': API_KEY}
    response = requests.get(url, headers=headers)
    res=response.json()
    match_ids.extend(res)
    if len(res) == 100 :
        index +=100
        get_all_ranked_league_match_by_uuid(puuid,start_date,region,index,match_ids)
    return match_ids



match_ids =get_all_ranked_league_match_by_uuid(puuid=puuid,start_date=timestamp_season14_start,region='asia')
len(match_ids)
# Out:
# 203

# %%
def get_match_info_by_match_id(match_id,region):
    url= f'https://{region}.api.riotgames.com/lol/match/v5/matches/{match_id}'
    headers = {'X-Riot-Token': API_KEY}
    response = requests.get(url, headers=headers)
    return response.json()

match_data= get_match_info_by_match_id(match_id=match_ids[0],region='asia')
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6980019239',
#   'participants': ['mNRrGOOOtsj69XMaNOFIPVqllX62NI3Un1NQSFRrrlU1DzdnHJpn5eYXMkeNJ4VItAiHuwh7BBT8Bw',
#    'o_utJ8jyCeEfybHFSeT5jG03t2cafJkKOtV5IVb7fWyqrSZGPDbSVeTxlAbZct430jUWdy6YkspkEw',
#    'DQ6cdLQixEkUiPCTMI0OWtu59_h14ADFXZTNoHM363e8j7F7Z0yu_bTtdmKuQXY4RQuJY9M-DfDn1Q',
#    'Pdj2IcWeu_tOex0CQ70kQk2JxZaaD3cEIvfUGtkfiO2z5OmpQxMG2R5JbB5zkPynt2Eyp2T4BbxNtA',
#    'xktHNd4jzVv3VRHQ_abi2sykYjZ1w3yEfahecne5V01JwFvLPWpUE_4RCknEEwqf9IEkIX20N_YNeQ',
#    'Pi0Hf3VCMwNKRFXidUi5W_8LE70rREG0zBkkqYpp7G0sd11NHjBOfaPVbt65_g9VZhp3d4q1gEa53w',
#    'Equcb08pk5PL-Ego1PUQG3b_AljWRX2lWgOhU6dhyJyv1WO9M8jtv7u-ZVz54bxTXCZORx8xj5ls2g',
#    'kF5S8QZxxndtBC5R8YCvARKQfR0tI1FA2NwfrHwzG5GMqc1AbZo2xr7UiOjFiw8B3x60ffWfkwgFuQ',
#    '1o3fc-sZNshzoMMujUWbUOMLCunkhH1xhlo2gdcANa2CK_wjZsyntPEmx5OpS0BXqfen7_XFIwrPVw',
#    'KOHsQONTk-ZqLgOBXFuzCVWi0RgiXdX6dLX4kVOOFkHzdlzHyy3Jp5yIboWgYtPsICkmuf37UE5Ttg']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1709887584494,
#   'gameDuration': 2093,
#   'gameEndTimestamp': 1709889695882,
#   'gameId': 6980019239,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-6980019239',
#   'gameStartTimestamp': 1709887602224,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '14.5.565.1230',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 35,
#     'assists': 12,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 189,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 255.60117778925178,
#      'damageTakenOnTeamPercentage': 0.3255920624255811,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1777.0734043999998,
#      'earliestDragonTakedown': 570.9176947,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 56,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 3,
#      'fullTeamTakedown': 5,
#      'gameLength': 2093.8717060999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 312.35555599329757,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 11,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.5555555555555556,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.5,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 7,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 34,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3075, 6665],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 6,
#      'maxKillDeficit': 11,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 1,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 13,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 10,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 16,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 3,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 14,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.07187204892441594,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 1.2228128910064697,
#      'visionScorePerMinute': 1.4202889720524157,
#      'wardTakedowns': 9,
#      'wardTakedownsBefore20M': 4,
#      'wardsGuarded': 1},
#     'champExperience': 14400,
#     'champLevel': 15,
#     'championId': 33,
#     'championName': 'Rammus',
#     'championTransform': 0,
#     'commandPings': 27,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 2578,
#     'damageDealtToObjectives': 6669,
#     'damageDealtToTurrets': 2578,
#     'damageSelfMitigated': 79676,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 3,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 17,
#     'goldEarned': 10900,
#     'goldSpent': 8900,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3075,
#     'item1': 6665,
#     'item2': 3876,
#     'item3': 3009,
#     'item4': 3066,
#     'item5': 1057,
#     'item6': 3364,
#     'itemsPurchased': 31,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'TOP',
#     'largestCriticalStrike': 102,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 475,
#     'magicDamageDealt': 68148,
#     'magicDamageDealtToChampions': 7881,
#     'magicDamageTaken': 27974,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 26,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5001, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 716, 'var2': 1113, 'var3': 0},
#         {'perk': 8446, 'var1': 1457, 'var2': 0, 'var3': 0},
#         {'perk': 8429, 'var1': 65, 'var2': 26, 'var3': 13},
#         {'perk': 8451, 'var1': 227, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5},
#         {'perk': 8316, 'var1': 3400, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 16236,
#     'physicalDamageDealtToChampions': 1038,
#     'physicalDamageTaken': 18507,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 28,
#     'pushPings': 0,
#     'puuid': 'mNRrGOOOtsj69XMaNOFIPVqllX62NI3Un1NQSFRrrlU1DzdnHJpn5eYXMkeNJ4VItAiHuwh7BBT8Bw',
#     'quadraKills': 0,
#     'riotIdGameName': '룰루랄라리루리',
#     'riotIdTagline': 'KR1',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 61,
#     'spell2Casts': 91,
#     'spell3Casts': 27,
#     'spell4Casts': 10,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 12,
#     'summoner2Casts': 6,
#     'summoner2Id': 6,
#     'summonerId': 'pkka5MS-EnVMa3yqODZaWd5G--lo29jI90znB3fto5lY3_eipuxD7Y7neA',
#     'summonerLevel': 81,
#     'summonerName': '룰루랄라리루리',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 34,
#     'timePlayed': 2093,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 99928,
#     'totalDamageDealtToChampions': 8919,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 47312,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 6901,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 139,
#     'totalTimeCCDealt': 241,
#     'totalTimeSpentDead': 215,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 15543,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 830,
#     'turretKills': 0,
#     'turretTakedowns': 4,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 49,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 9,
#     'wardsPlaced': 19,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 32,
#     'assists': 14,
#     'baronKills': 1,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 370,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 96,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 975,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7573853978636556,
#      'controlWardsPlaced': 6,
#      'damagePerMinute': 1083.2856125530318,
#      'damageTakenOnTeamPercentage': 0.2565563252653678,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1777.0734043999998,
#      'earliestDragonTakedown': 570.9176947,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 824.8880615234375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 16,
#      'enemyJungleMonsterKills': 9,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 3,
#      'fullTeamTakedown': 5,
#      'gameLength': 2093.8717060999998,
#      'goldPerMinute': 452.1341939602754,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 10,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 57.6000000834465,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.5,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.75,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnLanersEarlyJungleAsJungler': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 2,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6653, 3116, 3137, 3089],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 4,
#      'maxKillDeficit': 11,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -40.90000006556511,
#      'multiKillOneSpell': 1,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 15,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'shortestTimeToAceFromFirstTakedown': 45.85179029999995,
#      'skillshotsDodged': 11,
#      'skillshotsHit': 23,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 14,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 6,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 21,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 5,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.30460719006828213,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.059552788734436035,
#      'visionScorePerMinute': 1.2608332732967102,
#      'wardTakedowns': 9,
#      'wardTakedownsBefore20M': 7,
#      'wardsGuarded': 1},
#     'champExperience': 16861,
#     'champLevel': 17,
#     'championId': 63,
#     'championName': 'Brand',
#     'championTransform': 0,
#     'commandPings': 20,
#     'consumablesPurchased': 9,
#     'damageDealtToBuildings': 4630,
#     'damageDealtToObjectives': 42194,
#     'damageDealtToTurrets': 4630,
#     'damageSelfMitigated': 15382,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 12,
#     'goldEarned': 15778,
#     'goldSpent': 14290,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3116,
#     'item1': 6653,
#     'item2': 3089,
#     'item3': 3020,
#     'item4': 3137,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 25,
#     'killingSprees': 2,
#     'kills': 7,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 568,
#     'magicDamageDealt': 243595,
#     'magicDamageDealtToChampions': 34690,
#     'magicDamageTaken': 15646,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 1,
#     'neutralMinionsKilled': 172,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 39,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 1802, 'var2': 0, 'var3': 0},
#         {'perk': 8126, 'var1': 1395, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 15746,
#     'physicalDamageDealtToChampions': 694,
#     'physicalDamageTaken': 21588,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5982,
#     'pushPings': 0,
#     'puuid': 'o_utJ8jyCeEfybHFSeT5jG03t2cafJkKOtV5IVb7fWyqrSZGPDbSVeTxlAbZct430jUWdy6YkspkEw',
#     'quadraKills': 0,
#     'riotIdGameName': '정글을어떤식으로해야잘할수있을까',
#     'riotIdTagline': '고민해보기',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 124,
#     'spell2Casts': 136,
#     'spell3Casts': 95,
#     'spell4Casts': 15,
#     'subteamPlacement': 0,
#     'summoner1Casts': 16,
#     'summoner1Id': 11,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'pYTME01XAkn1zLIdwzFXntoNzomKt1ay0D-EbcqexAWFiCv0',
#     'summonerLevel': 392,
#     'summonerName': '베네 기운 받는중',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 41,
#     'timePlayed': 2093,
#     'totalAllyJungleMinionsKilled': 129,
#     'totalDamageDealt': 334024,
#     'totalDamageDealtToChampions': 37804,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 37280,
#     'totalEnemyJungleMinionsKilled': 10,
#     'totalHeal': 13655,
#     'totalHealsOnTeammates': 824,
#     'totalMinionsKilled': 61,
#     'totalTimeCCDealt': 617,
#     'totalTimeSpentDead': 177,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 74684,
#     'trueDamageDealtToChampions': 2419,
#     'trueDamageTaken': 46,
#     'turretKills': 1,
#     'turretTakedowns': 4,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 44,
#     'visionWardsBoughtInGame': 8,
#     'wardsKilled': 9,
#     'wardsPlaced': 20,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 9,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 363,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 450,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 955.8946593619097,
#      'damageTakenOnTeamPercentage': 0.19041161909186907,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1777.0734043999998,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 3,
#      'fullTeamTakedown': 5,
#      'gameLength': 2093.8717060999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 473.6872974585824,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.6428571428571429,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 70,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3508, 6676, 6675, 3033],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 48.39999997615814,
#      'maxKillDeficit': 11,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 1,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 1,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 36.205354799999895,
#      'skillshotsDodged': 11,
#      'skillshotsHit': 1,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 5,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 18,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 1,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.26878635035435294,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'teleportTakedowns': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.4539911150932312,
#      'visionScorePerMinute': 0.47576020853447565,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 17392,
#     'champLevel': 17,
#     'championId': 41,
#     'championName': 'Gangplank',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 2356,
#     'damageDealtToObjectives': 5955,
#     'damageDealtToTurrets': 2356,
#     'damageSelfMitigated': 12211,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 5,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 16530,
#     'goldSpent': 14300,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6675,
#     'item1': 3508,
#     'item2': 3158,
#     'item3': 6676,
#     'item4': 3033,
#     'item5': 1018,
#     'item6': 3363,
#     'itemsPurchased': 24,
#     'killingSprees': 3,
#     'kills': 9,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 1346,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 506,
#     'magicDamageDealt': 9395,
#     'magicDamageDealtToChampions': 6713,
#     'magicDamageTaken': 19563,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 3,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8229, 'var1': 1472, 'var2': 0, 'var3': 0},
#         {'perk': 8224, 'var1': 806, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 22, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 479, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 924, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 208926,
#     'physicalDamageDealtToChampions': 21124,
#     'physicalDamageTaken': 7755,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 907,
#     'pushPings': 0,
#     'puuid': 'DQ6cdLQixEkUiPCTMI0OWtu59_h14ADFXZTNoHM363e8j7F7Z0yu_bTtdmKuQXY4RQuJY9M-DfDn1Q',
#     'quadraKills': 0,
#     'riotIdGameName': '리즈윈',
#     'riotIdTagline': '332',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 190,
#     'spell2Casts': 29,
#     'spell3Casts': 135,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 12,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'XWxJMQJBCTddG2KAjp1bkepdb2X7ssQLd0ROA1kLZvXpGMHJVObeDyWdkg',
#     'summonerLevel': 87,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 18,
#     'timePlayed': 2093,
#     'totalAllyJungleMinionsKilled': 4,
#     'totalDamageDealt': 230472,
#     'totalDamageDealtToChampions': 33358,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 27669,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 5705,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 236,
#     'totalTimeCCDealt': 298,
#     'totalTimeSpentDead': 200,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 12149,
#     'trueDamageDealtToChampions': 5521,
#     'trueDamageTaken': 350,
#     'turretKills': 0,
#     'turretTakedowns': 3,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 16,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 3,
#     'wardsPlaced': 10,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 2,
#     'assists': 9,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 297,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5891212813594835,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 803.7552007291533,
#      'damageTakenOnTeamPercentage': 0.1869245512041733,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1777.0734043999998,
#      'earliestDragonTakedown': 1355.9896666,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'flawlessAces': 3,
#      'fullTeamTakedown': 5,
#      'gameLength': 2093.8717060999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 471.91907934654915,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.7142857142857144,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.6785714285714286,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 8,
#      'laneMinionsFirst10Minutes': 64,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3095, 6699, 3094, 3036],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 76,
#      'maxKillDeficit': 11,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 1,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 14,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'shortestTimeToAceFromFirstTakedown': 36.205354799999895,
#      'skillshotsDodged': 16,
#      'skillshotsHit': 51,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 6,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 19,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.22600652160409812,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.1593695878982544,
#      'visionScorePerMinute': 1.147984444421352,
#      'wardTakedowns': 4,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 14921,
#     'champLevel': 16,
#     'championId': 236,
#     'championName': 'Lucian',
#     'championTransform': 0,
#     'commandPings': 14,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 5995,
#     'damageDealtToObjectives': 15664,
#     'damageDealtToTurrets': 5995,
#     'damageSelfMitigated': 10492,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 7,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 2,
#     'goldEarned': 16468,
#     'goldSpent': 13400,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3095,
#     'item1': 6699,
#     'item2': 3036,
#     'item3': 3158,
#     'item4': 3094,
#     'item5': 1055,
#     'item6': 3363,
#     'itemsPurchased': 26,
#     'killingSprees': 4,
#     'kills': 10,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 567,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 502,
#     'magicDamageDealt': 25277,
#     'magicDamageDealtToChampions': 8128,
#     'magicDamageTaken': 15473,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 12,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 1103, 'var2': 927, 'var3': 0},
#         {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 749, 'var3': 0},
#         {'perk': 8237, 'var1': 645, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 169895,
#     'physicalDamageDealtToChampions': 18136,
#     'physicalDamageTaken': 11243,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6521,
#     'pushPings': 0,
#     'puuid': 'Pdj2IcWeu_tOex0CQ70kQk2JxZaaD3cEIvfUGtkfiO2z5OmpQxMG2R5JbB5zkPynt2Eyp2T4BbxNtA',
#     'quadraKills': 0,
#     'riotIdGameName': '깅아챌',
#     'riotIdTagline': '2007',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 97,
#     'spell2Casts': 79,
#     'spell3Casts': 98,
#     'spell4Casts': 23,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 14,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': 'DC4howEqqvH-9N82svISGwGQbbhYN7Jh1_TTirz2jxNmVgCqdd0EtNNWhQ',
#     'summonerLevel': 215,
#     'summonerName': '빈 하늘에 불꽃을 그린다',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 2,
#     'timePlayed': 2093,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 197640,
#     'totalDamageDealtToChampions': 28049,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 27162,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3442,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 247,
#     'totalTimeCCDealt': 44,
#     'totalTimeSpentDead': 171,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2467,
#     'trueDamageDealtToChampions': 1784,
#     'trueDamageTaken': 445,
#     'turretKills': 1,
#     'turretTakedowns': 4,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 40,
#     'visionWardsBoughtInGame': 5,
#     'wardsKilled': 4,
#     'wardsPlaced': 14,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 25,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 2,
#      'abilityUses': 347,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 1,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.44654278076163356,
#      'controlWardsPlaced': 6,
#      'damagePerMinute': 457.79966687484824,
#      'damageTakenOnTeamPercentage': 0.04051544201300875,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 0,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1777.0734043999998,
#      'earliestDragonTakedown': 1355.9896666,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 18099.748046875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 30,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fasterSupportQuestCompletion': 1,
#      'firstTurretKilled': 0,
#      'flawlessAces': 3,
#      'fullTeamTakedown': 5,
#      'gameLength': 2093.8717060999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 279.8325211284539,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 12,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 25,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.8928571428571429,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 1,
#      'laneMinionsFirst10Minutes': 22,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [4005, 2065, 3165],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 8,
#      'maxKillDeficit': 11,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 20,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 2,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 36.205354799999895,
#      'skillshotsDodged': 14,
#      'skillshotsHit': 26,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 41,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 25,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.12872788904885088,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.11873644590377808,
#      'visionScorePerMinute': 2.6418128247063972,
#      'wardTakedowns': 13,
#      'wardTakedownsBefore20M': 6,
#      'wardsGuarded': 0},
#     'champExperience': 13793,
#     'champLevel': 15,
#     'championId': 267,
#     'championName': 'Nami',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 11,
#     'damageDealtToBuildings': 1956,
#     'damageDealtToObjectives': 3569,
#     'damageDealtToTurrets': 1956,
#     'damageSelfMitigated': 1749,
#     'dangerPings': 0,
#     'deaths': 0,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 1,
#     'goldEarned': 9765,
#     'goldSpent': 8325,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3870,
#     'item1': 2065,
#     'item2': 4005,
#     'item3': 3165,
#     'item4': 3158,
#     'item5': 2055,
#     'item6': 3364,
#     'itemsPurchased': 26,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 0,
#     'magicDamageDealt': 29852,
#     'magicDamageDealtToChampions': 14741,
#     'magicDamageTaken': 4016,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 2,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 884, 'var2': 2899, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 842, 'var3': 0},
#         {'perk': 8210, 'var1': 23, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 544, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 8099,
#     'physicalDamageDealtToChampions': 1234,
#     'physicalDamageTaken': 1777,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6544,
#     'pushPings': 0,
#     'puuid': 'xktHNd4jzVv3VRHQ_abi2sykYjZ1w3yEfahecne5V01JwFvLPWpUE_4RCknEEwqf9IEkIX20N_YNeQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'Vasshu Sutanpido',
#     'riotIdTagline': '1996',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 42,
#     'spell2Casts': 125,
#     'spell3Casts': 166,
#     'spell4Casts': 14,
#     'subteamPlacement': 0,
#     'summoner1Casts': 0,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 7,
#     'summonerId': 'OlUQCEBs8gsjg9hnfy_qraiO5tNsTS8H-oGfUxIwXYP_v4r4NIMMftW0Sw',
#     'summonerLevel': 48,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 50,
#     'timePlayed': 2093,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 39092,
#     'totalDamageDealtToChampions': 15976,
#     'totalDamageShieldedOnTeammates': 2949,
#     'totalDamageTaken': 5887,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 16933,
#     'totalHealsOnTeammates': 15150,
#     'totalMinionsKilled': 40,
#     'totalTimeCCDealt': 315,
#     'totalTimeSpentDead': 0,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 1139,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 94,
#     'turretKills': 3,
#     'turretTakedowns': 4,
#     'turretsLost': 7,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 92,
#     'visionWardsBoughtInGame': 9,
#     'wardsKilled': 13,
#     'wardsPlaced': 47,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 7,
#     'assists': 6,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 638,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 3,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 905.8525309116599,
#      'damageTakenOnTeamPercentage': 0.15949900125887748,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 2,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1305.6745957,
#      'earliestDragonTakedown': 1668.2882444,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 678.0343627929688,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 6,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 739.2950588,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 2093.8717060999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 439.9819619158663,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 6.5,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.48148148148148145,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 9,
#      'laneMinionsFirst10Minutes': 101,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6653, 4633, 3137, 3041, 3102],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 138.40000000596046,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 4,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 7,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
# ...
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 12,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 7,
#      'skillshotsHit': 20,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 40,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 15,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.1419119564522717,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 6,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 1,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.1347343921661377,
#      'visionScorePerMinute': 2.997755724607376,
#      'wardTakedowns': 17,
#      'wardTakedownsBefore20M': 9,
#      'wardsGuarded': 0},
#     'champExperience': 11019,
#     'champLevel': 13,
#     'championId': 235,
#     'championName': 'Senna',
#     'championTransform': 0,
#     'commandPings': 17,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 6226,
#     'damageDealtToObjectives': 15559,
#     'damageDealtToTurrets': 6226,
#     'damageSelfMitigated': 8217,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 16,
#     'enemyVisionPings': 9,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 19,
#     'goldEarned': 12347,
#     'goldSpent': 11350,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3142,
#     'item1': 3877,
#     'item2': 6701,
#     'item3': 3814,
#     'item4': 3035,
#     'item5': 3009,
#     'item6': 3364,
#     'itemsPurchased': 28,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 559,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 842,
#     'magicDamageDealt': 0,
#     'magicDamageDealtToChampions': 0,
#     'magicDamageTaken': 14033,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 36,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2483, 'var2': 2357, 'var3': 0},
#         {'perk': 8009, 'var1': 2297, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 19, 'var2': 30, 'var3': 0},
#         {'perk': 8017, 'var1': 1029, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8410, 'var1': 66, 'var2': 0, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 89267,
#     'physicalDamageDealtToChampions': 16214,
#     'physicalDamageTaken': 8431,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5388,
#     'pushPings': 0,
#     'puuid': '1o3fc-sZNshzoMMujUWbUOMLCunkhH1xhlo2gdcANa2CK_wjZsyntPEmx5OpS0BXqfen7_XFIwrPVw',
#     'quadraKills': 0,
#     'riotIdGameName': '서정언',
#     'riotIdTagline': '123',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 89,
#     'spell2Casts': 34,
#     'spell3Casts': 31,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 7,
#     'summonerId': 'ocH-mBLFPhSfZeNyfesfm8XHOnpQBs8iv6-NCT1dlPX8BEDy2oYC9sf9nA',
#     'summonerLevel': 406,
#     'summonerName': 'wha1e',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 21,
#     'timePlayed': 2093,
#     'totalAllyJungleMinionsKilled': 4,
#     'totalDamageDealt': 94635,
#     'totalDamageDealtToChampions': 16759,
#     'totalDamageShieldedOnTeammates': 2078,
#     'totalDamageTaken': 24018,
#     'totalEnemyJungleMinionsKilled': 4,
#     'totalHeal': 17854,
#     'totalHealsOnTeammates': 7985,
#     'totalMinionsKilled': 71,
#     'totalTimeCCDealt': 319,
#     'totalTimeSpentDead': 141,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 5368,
#     'trueDamageDealtToChampions': 545,
#     'trueDamageTaken': 1553,
#     'turretKills': 2,
#     'turretTakedowns': 6,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 104,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 17,
#     'wardsPlaced': 44,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 5,
#     'assists': 11,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 162,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6985790152465732,
#      'controlWardsPlaced': 3,
#      'damagePerMinute': 330.0512531190127,
#      'damageTakenOnTeamPercentage': 0.23053525078097856,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1305.6745957,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 2828.59326171875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 13,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 739.2950588,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 2093.8717060999998,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 316.32383278685353,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.4444444444444444,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 1,
#      'landSkillShotsEarlyGame': 7,
#      'laneMinionsFirst10Minutes': 69,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6664, 3110, 6665],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 16,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 10,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 5,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 15,
#      'skillshotsHit': 49,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 5,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 12,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.09752722917532881,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.13746225833892822,
#      'visionScorePerMinute': 0.9901798784078123,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 12092,
#     'champLevel': 14,
#     'championId': 223,
#     'championName': 'TahmKench',
#     'championTransform': 0,
#     'commandPings': 17,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 119,
#     'damageDealtToObjectives': 1564,
#     'damageDealtToTurrets': 119,
#     'damageSelfMitigated': 56773,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 20,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 20,
#     'goldEarned': 11039,
#     'goldSpent': 10925,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6664,
#     'item1': 3110,
#     'item2': 6665,
#     'item3': 1011,
#     'item4': 3047,
#     'item5': 1054,
#     'item6': 3364,
#     'itemsPurchased': 23,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1002,
#     'magicDamageDealt': 54864,
#     'magicDamageDealtToChampions': 10570,
#     'magicDamageTaken': 17564,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore10': 0,
#      'playerScore11': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 20,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5001, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8465, 'var1': 2714, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 1012, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 1546, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 851, 'var2': 1165, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#         {'perk': 8316, 'var1': 3251, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 17577,
#     'physicalDamageDealtToChampions': 947,
#     'physicalDamageTaken': 17319,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore10': 0,
#     'playerScore11': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 22,
#     'pushPings': 0,
#     'puuid': 'KOHsQONTk-ZqLgOBXFuzCVWi0RgiXdX6dLX4kVOOFkHzdlzHyy3Jp5yIboWgYtPsICkmuf37UE5Ttg',
#     'quadraKills': 0,
#     'riotIdGameName': '나혼자만레벨업',
#     'riotIdTagline': '911',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 115,
#     'spell2Casts': 22,
#     'spell3Casts': 7,
#     'spell4Casts': 18,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 12,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'gJf4NijC6U9rWhhnc52WNdk_pSQjqifCFFLR-pSOxO9tDIxC7smDo3BZLQ',
#     'summonerLevel': 87,
#     'summonerName': 'mei ge ming tian',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 24,
#     'timePlayed': 2093,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 78009,
#     'totalDamageDealtToChampions': 11518,
#     'totalDamageShieldedOnTeammates': 2309,
#     'totalDamageTaken': 37358,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 9441,
#     'totalHealsOnTeammates': 519,
#     'totalMinionsKilled': 176,
#     'totalTimeCCDealt': 902,
#     'totalTimeSpentDead': 197,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 5567,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 2473,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 34,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 3,
#     'wardsPlaced': 13,
#     'win': False}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 268, 'pickTurn': 1},
#      {'championId': 107, 'pickTurn': 2},
#      {'championId': 76, 'pickTurn': 3},
#      {'championId': 429, 'pickTurn': 4},
#      {'championId': 555, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': False, 'kills': 1},
#      'champion': {'first': False, 'kills': 28},
#      'dragon': {'first': True, 'kills': 2},
#      'horde': {'first': True, 'kills': 3},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 5}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 126, 'pickTurn': 6},
#      {'championId': 107, 'pickTurn': 7},
#      {'championId': 35, 'pickTurn': 8},
#      {'championId': 901, 'pickTurn': 9},
#      {'championId': 119, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 28},
#      'dragon': {'first': False, 'kills': 3},
#      'horde': {'first': False, 'kills': 3},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': True, 'kills': 1},
#      'tower': {'first': True, 'kills': 7}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
def parth_match_data
